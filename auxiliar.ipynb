# %%
import pandas as pd
dataset_url = pd.read_csv("./dataset/ADMISSIONS.csv")
x = dataset_url["diagnosis"].value_counts().keys()
y =  dataset_url["diagnosis"].value_counts().values
top5_d = x[0:5]
top5_dy = y[0:5]

# %%
top5_d
# Out:
# Index(['SEPSIS', 'PNEUMONIA', 'SHORTNESS OF BREATH', 'FEVER',
#        'CONGESTIVE HEART FAILURE'],
#       dtype='object')

# %%
top5_dy
# Out:
# array([10,  8,  4,  4,  3], dtype=int64)

# %%
dataset_url['diagnosis'].value_counts()
# Out:
# SEPSIS                                  10
# PNEUMONIA                                8
# SHORTNESS OF BREATH                      4
# FEVER                                    4
# CONGESTIVE HEART FAILURE                 3
#                                         ..
# SEPSIS;TELEMETRY                         1
# HYPOTENSION;TELEMETRY                    1
# CRITICAL AORTIC STENOSIS/HYPOTENSION     1
# OVERDOSE                                 1
# CHOLANGITIS                              1
# Name: diagnosis, Length: 95, dtype: int64

# %%
#Pruebas de laboratorio
labevents = pd.read_csv("./dataset/LABEVENTS.csv")
labitems = pd.read_csv("./dataset/D_LABITEMS.csv")
lab = labevents.merge(labitems, left_on='itemid', right_on='itemid')

# %%
lab.head()
# Out:
#    row_id_x  subject_id  hadm_id  itemid            charttime value  valuenum  \
# 0   6244563       10006      NaN   50868  2164-09-24 20:21:00    19      19.0
# 1   6244601       10006      NaN   50868  2164-09-25 05:25:00    15      15.0
# 2   6244636       10006      NaN   50868  2164-09-26 07:00:00    17      17.0
# 3   6244690       10006      NaN   50868  2164-09-28 08:20:00    18      18.0
# 4   6244705       10006      NaN   50868  2164-09-29 05:10:00    17      17.0
#
#   valueuom flag  row_id_y      label  fluid   category loinc_code
# 0    mEq/L  NaN        69  Anion Gap  Blood  Chemistry     1863-0
# 1    mEq/L  NaN        69  Anion Gap  Blood  Chemistry     1863-0
# 2    mEq/L  NaN        69  Anion Gap  Blood  Chemistry     1863-0
# 3    mEq/L  NaN        69  Anion Gap  Blood  Chemistry     1863-0
# 4    mEq/L  NaN        69  Anion Gap  Blood  Chemistry     1863-0

# %%
user_filter = 10011
lab[lab["subject_id"] == user_filter]
# Out:
#        row_id_x  subject_id   hadm_id  itemid            charttime value  \
# 61      6247419       10011  105331.0   50868  2126-08-15 01:30:00    12
# 62      6247503       10011  105331.0   50868  2126-08-16 02:20:00    10
# 63      6247544       10011  105331.0   50868  2126-08-16 15:00:00     9
# 64      6247563       10011  105331.0   50868  2126-08-16 18:00:00    12
# 65      6247586       10011  105331.0   50868  2126-08-17 01:00:00    10
# ...         ...         ...       ...     ...                  ...   ...
# 71933   6248035       10011  105331.0   51074  2126-08-26 20:45:00   NEG
# 71952   6248036       10011  105331.0   51075  2126-08-26 20:45:00   NEG
# 71971   6248037       10011  105331.0   51079  2126-08-26 20:45:00   NEG
# 71990   6248039       10011  105331.0   51090  2126-08-26 20:45:00   NEG
# 72009   6248040       10011  105331.0   51092  2126-08-26 20:45:00   NEG
#
#        valuenum valueuom flag  row_id_y                         label  fluid  \
# 61         12.0    mEq/L  NaN        69                     Anion Gap  Blood
# 62         10.0    mEq/L  NaN        69                     Anion Gap  Blood
# 63          9.0    mEq/L  NaN        69                     Anion Gap  Blood
# 64         12.0    mEq/L  NaN        69                     Anion Gap  Blood
# 65         10.0    mEq/L  NaN        69                     Anion Gap  Blood
# ...         ...      ...  ...       ...                           ...    ...
# 71933       NaN      NaN  NaN       274     Barbiturate Screen, Urine  Urine
# 71952       NaN      NaN  NaN       275  Benzodiazepine Screen, Urine  Urine
# 71971       NaN      NaN  NaN       279                Cocaine, Urine  Urine
# 71990       NaN      NaN  NaN       290              Methadone, Urine  Urine
# 72009       NaN      NaN  NaN       292          Opiate Screen, Urine  Urine
#
#         category loinc_code
# 61     Chemistry     1863-0
# 62     Chemistry     1863-0
# 63     Chemistry     1863-0
# 64     Chemistry     1863-0
# 65     Chemistry     1863-0
# ...          ...        ...
# 71933  Chemistry     3377-9
# 71952  Chemistry     3390-2
# 71971  Chemistry     3397-7
# 71990  Chemistry     3773-9
# 72009  Chemistry     3879-4
#
# [700 rows x 14 columns]

# %%
lab = lab[lab["subject_id"] == user_filter]

# %%
type(lab)
# Out:
# pandas.core.frame.DataFrame

# %%
lab
# Out:
#        row_id_x  subject_id   hadm_id  itemid            charttime value  \
# 61      6247419       10011  105331.0   50868  2126-08-15 01:30:00    12
# 62      6247503       10011  105331.0   50868  2126-08-16 02:20:00    10
# 63      6247544       10011  105331.0   50868  2126-08-16 15:00:00     9
# 64      6247563       10011  105331.0   50868  2126-08-16 18:00:00    12
# 65      6247586       10011  105331.0   50868  2126-08-17 01:00:00    10
# ...         ...         ...       ...     ...                  ...   ...
# 71933   6248035       10011  105331.0   51074  2126-08-26 20:45:00   NEG
# 71952   6248036       10011  105331.0   51075  2126-08-26 20:45:00   NEG
# 71971   6248037       10011  105331.0   51079  2126-08-26 20:45:00   NEG
# 71990   6248039       10011  105331.0   51090  2126-08-26 20:45:00   NEG
# 72009   6248040       10011  105331.0   51092  2126-08-26 20:45:00   NEG
#
#        valuenum valueuom flag  row_id_y                         label  fluid  \
# 61         12.0    mEq/L  NaN        69                     Anion Gap  Blood
# 62         10.0    mEq/L  NaN        69                     Anion Gap  Blood
# 63          9.0    mEq/L  NaN        69                     Anion Gap  Blood
# 64         12.0    mEq/L  NaN        69                     Anion Gap  Blood
# 65         10.0    mEq/L  NaN        69                     Anion Gap  Blood
# ...         ...      ...  ...       ...                           ...    ...
# 71933       NaN      NaN  NaN       274     Barbiturate Screen, Urine  Urine
# 71952       NaN      NaN  NaN       275  Benzodiazepine Screen, Urine  Urine
# 71971       NaN      NaN  NaN       279                Cocaine, Urine  Urine
# 71990       NaN      NaN  NaN       290              Methadone, Urine  Urine
# 72009       NaN      NaN  NaN       292          Opiate Screen, Urine  Urine
#
#         category loinc_code
# 61     Chemistry     1863-0
# 62     Chemistry     1863-0
# 63     Chemistry     1863-0
# 64     Chemistry     1863-0
# 65     Chemistry     1863-0
# ...          ...        ...
# 71933  Chemistry     3377-9
# 71952  Chemistry     3390-2
# 71971  Chemistry     3397-7
# 71990  Chemistry     3773-9
# 72009  Chemistry     3879-4
#
# [700 rows x 14 columns]

# %%
caregivers = pd.read_csv("./dataset/caregivers.csv")

# %%
# tasa de mortalidad
filtered = dataset_url[dataset_url['discharge_location'].str.contains('DEAD')]
death_ratio = filtered.shape[0] / dataset_url['discharge_location'].shape[0]

# %%
death_ratio
# Out:
# 0.31007751937984496

# %%
x = dataset_url['discharge_location'].value_counts().keys()
y = dataset_url['discharge_location'].value_counts().values

# %%
x
# Out:
# Index(['DEAD/EXPIRED', 'SNF', 'HOME', 'HOME HEALTH CARE',
#        'REHAB/DISTINCT PART HOSP', 'ICF', 'LONG TERM CARE HOSPITAL',
#        'HOSPICE-HOME', 'DISCH-TRAN TO PSYCH HOSP',
#        'HOME WITH HOME IV PROVIDR'],
#       dtype='object')

# %%
dataset_url.drop_duplicates(inplace=True)
dataset_url['subject_id'].value_counts()
#¿Qué es el índice de reingreso?
#El reingreso ha sido definido como todo ingreso con idéntico diagnóstico principal en los 30 días siguientes al alta.
tasa_reingreso = dataset_url.groupby(['subject_id','diagnosis'])['subject_id'].count()

# %%
tasa_reingreso.value_counts()
#tasa de reingreso 2 a mas ingresos con las misma enfermedad.
# Out:
# 1    116
# 2      2
# 4      1
# 5      1
# Name: subject_id, dtype: int64

# %%
type(tasa_reingreso)
# Out:
# pandas.core.series.Series

# %%
tasa_re = tasa_reingreso.value_counts()

# %%
tasa_re.index
# Out:
# Int64Index([1, 2, 4, 5], dtype='int64')

# %%
tasa_re[tasa_re.index > 1].sum() / tasa_re.sum() * 100
# Out:
# 3.3333333333333335

# %%
tasa_reingreso.value_counts().keys()
# Out:
# Int64Index([1, 2, 4, 5], dtype='int64')

# %%
tasa_reingreso.index
# Out:
# MultiIndex([(10006, ...),
#             (10011, ...),
#             (10013, ...),
#             (10017, ...),
#             (10019, ...),
#             (10026, ...),
#             (10027, ...),
#             (10029, ...),
#             (10032, ...),
#             (10033, ...),
#             ...
#             (43881, ...),
#             (43909, ...),
#             (43927, ...),
#             (44083, ...),
#             (44083, ...),
#             (44083, ...),
#             (44154, ...),
#             (44212, ...),
#             (44222, ...),
#             (44228, ...)],
#            names=['subject_id', 'diagnosis'], length=120)

# %%
caregivers = pd.read_csv('./dataset/CAREGIVERS.csv')

# %%
caregivers.head()
# Out:
#    row_id   cgid label            description
# 0    2228  16174    RO              Read Only
# 1    2229  16175    RO              Read Only
# 2    2230  16176   Res  Resident/Fellow/PA/NP
# 3    2231  16177    RO              Read Only
# 4    2232  16178    RT            Respiratory

# %%
patients = pd.read_csv('./dataset/patients.csv')

# %%
patients
# Out:
#     row_id  subject_id gender                  dob                  dod  \
# 0     9467       10006      F  2094-03-05 00:00:00  2165-08-12 00:00:00
# 1     9472       10011      F  2090-06-05 00:00:00  2126-08-28 00:00:00
# 2     9474       10013      F  2038-09-03 00:00:00  2125-10-07 00:00:00
# 3     9478       10017      F  2075-09-21 00:00:00  2152-09-12 00:00:00
# 4     9479       10019      M  2114-06-20 00:00:00  2163-05-15 00:00:00
# ..     ...         ...    ...                  ...                  ...
# 95   31838       44083      M  2057-11-15 00:00:00  2114-02-20 00:00:00
# 96   31853       44154      M  1878-05-14 00:00:00  2178-05-15 00:00:00
# 97   31867       44212      F  2078-06-16 00:00:00  2124-01-29 00:00:00
# 98   31870       44222      M  2107-06-27 00:00:00  2182-08-03 00:00:00
# 99   31872       44228      F  2112-10-22 00:00:00  2171-04-14 00:00:00
#
#                dod_hosp              dod_ssn  expire_flag
# 0   2165-08-12 00:00:00  2165-08-12 00:00:00            1
# 1   2126-08-28 00:00:00                  NaN            1
# 2   2125-10-07 00:00:00  2125-10-07 00:00:00            1
# 3                   NaN  2152-09-12 00:00:00            1
# 4   2163-05-15 00:00:00  2163-05-15 00:00:00            1
# ..                  ...                  ...          ...
# 95  2114-02-20 00:00:00  2114-02-20 00:00:00            1
# 96  2178-05-15 00:00:00  2178-05-15 00:00:00            1
# 97                  NaN  2124-01-29 00:00:00            1
# 98  2182-08-03 00:00:00                  NaN            1
# 99  2171-04-14 00:00:00                  NaN            1
#
# [100 rows x 8 columns]

# %%
patients['gender'].value_counts()
# Out:
# F    55
# M    45
# Name: gender, dtype: int64

# %%
patient = patients.merge(admissions, left_on='subject_id', right_on='subject_id')

# %%
dataset_url = pd.read_csv("./dataset/ADMISSIONS.csv")

# %%
patients
# Out:
#     row_id  subject_id gender                  dob                  dod  \
# 0     9467       10006      F  2094-03-05 00:00:00  2165-08-12 00:00:00
# 1     9472       10011      F  2090-06-05 00:00:00  2126-08-28 00:00:00
# 2     9474       10013      F  2038-09-03 00:00:00  2125-10-07 00:00:00
# 3     9478       10017      F  2075-09-21 00:00:00  2152-09-12 00:00:00
# 4     9479       10019      M  2114-06-20 00:00:00  2163-05-15 00:00:00
# ..     ...         ...    ...                  ...                  ...
# 95   31838       44083      M  2057-11-15 00:00:00  2114-02-20 00:00:00
# 96   31853       44154      M  1878-05-14 00:00:00  2178-05-15 00:00:00
# 97   31867       44212      F  2078-06-16 00:00:00  2124-01-29 00:00:00
# 98   31870       44222      M  2107-06-27 00:00:00  2182-08-03 00:00:00
# 99   31872       44228      F  2112-10-22 00:00:00  2171-04-14 00:00:00
#
#                dod_hosp              dod_ssn  expire_flag  age
# 0   2165-08-12 00:00:00  2165-08-12 00:00:00            1    0
# 1   2126-08-28 00:00:00                  NaN            1    0
# 2   2125-10-07 00:00:00  2125-10-07 00:00:00            1    0
# 3                   NaN  2152-09-12 00:00:00            1    0
# 4   2163-05-15 00:00:00  2163-05-15 00:00:00            1    0
# ..                  ...                  ...          ...  ...
# 95  2114-02-20 00:00:00  2114-02-20 00:00:00            1    0
# 96  2178-05-15 00:00:00  2178-05-15 00:00:00            1    0
# 97                  NaN  2124-01-29 00:00:00            1    0
# 98  2182-08-03 00:00:00                  NaN            1    0
# 99  2171-04-14 00:00:00                  NaN            1    0
#
# [100 rows x 9 columns]

# %%
#pacientes por edad
#int(patients['dod']) - int(patients['dob'])
yearnac = pd.to_datetime(patients['dob'])
yearmu = pd.to_datetime(patients['dod'])
patients['age'] = yearmu.dt.year - yearnac.dt.year
# Out:
# 0    2094-03-05
# 1    2090-06-05
# 2    2038-09-03
# 3    2075-09-21
# 4    2114-06-20
#         ...
# 95   2057-11-15
# 96   1878-05-14
# 97   2078-06-16
# 98   2107-06-27
# 99   2112-10-22
# Name: dob, Length: 100, dtype: datetime64[ns]

# %%
yearmu = pd.to_datetime(patients['dod'])
yearmu
# Out:
# 0    2165-08-12
# 1    2126-08-28
# 2    2125-10-07
# 3    2152-09-12
# 4    2163-05-15
#         ...
# 95   2114-02-20
# 96   2178-05-15
# 97   2124-01-29
# 98   2182-08-03
# 99   2171-04-14
# Name: dod, Length: 100, dtype: datetime64[ns]

# %%
patients['age'] = yearmu.dt.year - yearnac.dt.year

# %%
patients['age']
# Out:
# 0      71
# 1      36
# 2      87
# 3      77
# 4      49
#      ...
# 95     57
# 96    300
# 97     46
# 98     75
# 99     59
# Name: age, Length: 100, dtype: int64

# %%
dataset_url
# Out:
#      row_id  subject_id  hadm_id            admittime            dischtime  \
# 0     12258       10006   142345  2164-10-23 21:09:00  2164-11-01 17:15:00
# 1     12263       10011   105331  2126-08-14 22:32:00  2126-08-28 18:59:00
# 2     12265       10013   165520  2125-10-04 23:36:00  2125-10-07 15:13:00
# 3     12269       10017   199207  2149-05-26 17:19:00  2149-06-03 18:42:00
# 4     12270       10019   177759  2163-05-14 20:43:00  2163-05-15 12:00:00
# ..      ...         ...      ...                  ...                  ...
# 124   41055       44083   198330  2112-05-28 15:45:00  2112-06-07 16:50:00
# 125   41070       44154   174245  2178-05-14 20:29:00  2178-05-15 09:45:00
# 126   41087       44212   163189  2123-11-24 14:14:00  2123-12-30 14:31:00
# 127   41090       44222   192189  2180-07-19 06:55:00  2180-07-20 13:00:00
# 128   41092       44228   103379  2170-12-15 03:14:00  2170-12-24 18:00:00
#
#                deathtime admission_type         admission_location  \
# 0                    NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 1    2126-08-28 18:59:00      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 2    2125-10-07 15:13:00      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 3                    NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 4    2163-05-15 12:00:00      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# ..                   ...            ...                        ...
# 124                  NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 125  2178-05-15 09:45:00      EMERGENCY       EMERGENCY ROOM ADMIT
# 126                  NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 127                  NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 128                  NaN      EMERGENCY       EMERGENCY ROOM ADMIT
#
#            discharge_location insurance language           religion  \
# 0            HOME HEALTH CARE  Medicare      NaN           CATHOLIC
# 1                DEAD/EXPIRED   Private      NaN           CATHOLIC
# 2                DEAD/EXPIRED  Medicare      NaN           CATHOLIC
# 3                         SNF  Medicare      NaN           CATHOLIC
# 4                DEAD/EXPIRED  Medicare      NaN           CATHOLIC
# ..                        ...       ...      ...                ...
# 124                      HOME   Private     ENGL           CATHOLIC
# 125              DEAD/EXPIRED  Medicare     ENGL  PROTESTANT QUAKER
# 126  REHAB/DISTINCT PART HOSP  Medicare     ENGL       UNOBTAINABLE
# 127                      HOME  Medicare     ENGL           CATHOLIC
# 128          HOME HEALTH CARE   Private     ENGL      NOT SPECIFIED
#
#     marital_status               ethnicity            edregtime  \
# 0        SEPARATED  BLACK/AFRICAN AMERICAN  2164-10-23 16:43:00
# 1           SINGLE   UNKNOWN/NOT SPECIFIED                  NaN
# 2              NaN   UNKNOWN/NOT SPECIFIED                  NaN
# 3         DIVORCED                   WHITE  2149-05-26 12:08:00
# 4         DIVORCED                   WHITE                  NaN
# ..             ...                     ...                  ...
# 124         SINGLE                   WHITE  2112-05-28 13:16:00
# 125        MARRIED                   WHITE  2178-05-14 17:37:00
# 126         SINGLE  BLACK/AFRICAN AMERICAN                  NaN
# 127         SINGLE                   WHITE  2180-07-19 04:50:00
# 128         SINGLE                   WHITE  2170-12-15 02:22:00
#
#                edouttime                                          diagnosis  \
# 0    2164-10-23 23:00:00                                             SEPSIS
# 1                    NaN                                        HEPATITIS B
# 2                    NaN                                             SEPSIS
# 3    2149-05-26 19:45:00                                   HUMERAL FRACTURE
# 4                    NaN                                ALCOHOLIC HEPATITIS
# ..                   ...                                                ...
# 124  2112-05-28 17:30:00                               PERICARDIAL EFFUSION
# 125  2178-05-14 22:08:00                              ALTERED MENTAL STATUS
# 126                  NaN  ACUTE RESPIRATORY DISTRESS SYNDROME;ACUTE RENA...
# 127  2180-07-19 08:23:00                                        BRADYCARDIA
# 128  2170-12-15 05:25:00                                        CHOLANGITIS
#
#      hospital_expire_flag  has_chartevents_data
# 0                       0                     1
# 1                       1                     1
# 2                       1                     1
# 3                       0                     1
# 4                       1                     1
# ..                    ...                   ...
# 124                     0                     1
# 125                     1                     1
# 126                     0                     1
# 127                     0                     1
# 128                     0                     1
#
# [129 rows x 19 columns]

# %%
lab = labevents.merge(labitems, left_on='itemid', right_on='itemid')
# Out:
# array([10006, 10011, 10013, 10017, 10019, 10026, 10027, 10029, 10032,
#        10033, 10035, 10036, 10038, 10040, 10042, 10043, 10044, 10045,
#        10046, 10056, 10059, 10061, 10064, 10065, 10067, 10069, 10074,
#        10076, 10083, 10088, 10089, 10090, 10093, 10094, 10098, 10101,
#        10102, 10104, 10106, 10111, 10112, 10114, 10117, 10119, 10120,
#        10124, 10126, 10127, 10130, 10132, 40124, 40177, 40204, 40277,
#        40286, 40304, 40310, 40456, 40503, 40595, 40601, 40612, 40655,
#        40687, 41795, 41914, 41976, 41983, 42033, 42066, 42075, 42135,
#        42199, 42231, 42275, 42281, 42292, 42302, 42321, 42346, 42367,
#        42412, 42430, 42458, 43735, 43746, 43748, 43779, 43798, 43827,
#        43870, 43879, 43881, 43909, 43927, 44083, 44154, 44212, 44222,
#        44228], dtype=int64)

# %%
pd.unique(lab['subject_id'])[0:].shape
# Out:
# (0,)

# %%
pd.unique(lab['subject_id']).shape
# Out:
# (100,)

# %%
import pandas as pd

prescriptions = pd.read_csv('./EDA_UCI/dataset/PRESCRIPTIONS.csv')

# %%
prescriptions['startdate'].head()

prescriptions['startdate'] = prescriptions.startdate.apply(pd.to_datetime)

# %%
prescriptions['year'] = prescriptions['startdate'].dt.to_period('Y')

# %%
prescriptions['year']
# Out:
# 0        2146
# 1        2146
# 2        2146
# 3        2146
# 4        2146
#          ...
# 10393    2142
# 10394    2142
# 10395    2142
# 10396    2142
# 10397    2142
# Name: year, Length: 10398, dtype: period[A-DEC]

# %%
prescriptions['month'] = prescriptions['startdate'].dt.to_period('M')

# %%
prescriptions['month']
# Out:
# 0        2146-07
# 1        2146-07
# 2        2146-07
# 3        2146-07
# 4        2146-07
#           ...
# 10393    2142-11
# 10394    2142-11
# 10395    2142-11
# 10396    2142-11
# 10397    2142-11
# Name: month, Length: 10398, dtype: period[M]

# %%
y = prescriptions.groupby(['month'])['drug'].count()
x = prescriptions.groupby(['month'])['drug'].count().index

# %%
prescriptions['startdate'] = prescriptions.startdate.apply(pd.to_datetime)
prescriptions['month'] = prescriptions['startdate'].dt.to_period('M')
y = prescriptions.groupby(['month'])['drug'].count().values
x = prescriptions.groupby(['month'])['drug'].count().index

# %%
x = x.astype(str)

# %%
import matplotlib.pyplot as plt
plt.plot(x,y)
plt.show()

# %%
x
# Out:
# PeriodIndex(['2102-08', '2102-09', '2104-09', '2104-10', '2105-05', '2105-06',
#              '2106-08', '2107-01', '2107-02', '2107-03',
#              ...
#              '2201-05', '2201-08', '2201-09', '2201-11', '2201-12', '2202-01',
#              '2202-02', '2202-05', '2202-09', '2202-10'],
#             dtype='period[M]', name='month', length=136)

# %%
y
# Out:
# array([ 30,  17,  70,  64,  22,  90,  31, 337, 142, 120,  32,  18,  99,
#         97, 112,  11,  92,  70,  88,  29, 127, 103,  57,  53,  60,  62,
#         98, 111,  32,  36,  15,  91,   6, 185,  30,  63,  35,  35, 204,
#          5,   1,  64,  75,  20,  29,  32,  20,  77,  50,  59,   1,  40,
#         76,  83, 397, 211, 115, 243,  29, 109, 166,  88,  86,  15, 137,
#        259,  20,  32,  82,  23,  95,  37,  38, 114,  42,  40,  92,  39,
#         66,  41,  34,  99,  61,   2,  48,   6,  45, 161,  52,  75, 143,
#        294, 143,  34,  85,  29,  40,  62, 134,  17, 160,  19,  77,  33,
#         81,  66,  26,  83, 102,  58, 148, 109,  57,  41,  64,  45,  92,
#        193,  48,  16,  85, 137, 148,  65,  74,  15,  64,  44,  70,  54,
#          1,  38,  53,  48,  73, 125], dtype=int64)

# %%
from datetime import datetime

max_value = prescriptions['startdate'].max()
min_value = prescriptions['startdate'].min()
type(max_value)
max_value
# Out:
# Timestamp('2202-10-11 00:00:00')

# %%
str(max_value)
# Out:
# '2202-10-11 00:00:00'

# %%
max_value = datetime.strptime(str(max_value), '%Y-%m-%d %H:%M:%S')
min_value = datetime.strptime(str(min_value), '%Y-%m-%d %H:%M:%S')

# %%
datetime_object
# Out:
# datetime.datetime(2202, 11, 10, 0, 0)

# %%
filtered_prescriptions = prescriptions[(prescriptions['startdate'] > min_value) & (prescriptions['startdate'] < max_value)]

# %%
filtered_prescriptions
# Out:
#         row_id  subject_id  hadm_id  icustay_id  startdate  \
# 0        32600       42458   159647         NaN 2146-07-21
# 1        32601       42458   159647         NaN 2146-07-21
# 2        32602       42458   159647         NaN 2146-07-21
# 3        32603       42458   159647         NaN 2146-07-21
# 4        32604       42458   159647         NaN 2146-07-21
# ...        ...         ...      ...         ...        ...
# 10393  3609913       42430   100969    210474.0 2142-11-29
# 10394  3609914       42430   100969    210474.0 2142-11-30
# 10395  3609915       42430   100969         NaN 2142-11-26
# 10396  3609916       42430   100969         NaN 2142-11-26
# 10397  3609917       42430   100969         NaN 2142-11-26
#
#                    enddate drug_type                         drug  \
# 0      2146-07-22 00:00:00      MAIN  Pneumococcal Vac Polyvalent
# 1      2146-07-22 00:00:00      MAIN                    Bisacodyl
# 2      2146-07-22 00:00:00      MAIN                    Bisacodyl
# 3      2146-07-22 00:00:00      MAIN                        Senna
# 4      2146-07-21 00:00:00      MAIN     Docusate Sodium (Liquid)
# ...                    ...       ...                          ...
# 10393  2142-11-30 00:00:00      MAIN  Sodium Chloride 0.9%  Flush
# 10394  2142-11-30 00:00:00      MAIN                Acetaminophen
# 10395  2142-11-27 00:00:00      BASE         0.9% Sodium Chloride
# 10396  2142-11-27 00:00:00      BASE                          D5W
# 10397  2142-11-28 00:00:00      BASE        0.83% Sodium Chloride
#
#                      drug_name_poe            drug_name_generic  ...      gsn  \
# 0      Pneumococcal Vac Polyvalent  PNEUMOcoccal Vac Polyvalent  ...  48548.0
# 1                        Bisacodyl                    Bisacodyl  ...   2947.0
# 2                        Bisacodyl           Bisacodyl (Rectal)  ...   2944.0
# 3                            Senna                        Senna  ...  19964.0
# 4         Docusate Sodium (Liquid)     Docusate Sodium (Liquid)  ...   3017.0
# ...                            ...                          ...  ...      ...
# 10393  Sodium Chloride 0.9%  Flush  Sodium Chloride 0.9%  Flush  ...      NaN
# 10394                Acetaminophen       Acetaminophen (Rectal)  ...   4478.0
# 10395                          NaN                          NaN  ...   1210.0
# 10396                          NaN                          NaN  ...      NaN
# 10397                          NaN                          NaN  ...      NaN
#
#                ndc     prod_strength dose_val_rx dose_unit_rx form_val_disp  \
# 0        6494300.0  25mcg/0.5mL Vial         0.5           mL             1
# 1      536338101.0          5 mg Tab          10           mg             2
# 2      574705050.0  10mg Suppository          10           mg             1
# 3      904516561.0          1 Tablet           1          TAB             1
# 4      121054410.0      100mg UD Cup         100           mg             1
# ...            ...               ...         ...          ...           ...
# 10393          0.0           Syringe           3           mL           0.6
# 10394  713016550.0        650mg Supp         650           mg             1
# 10395  338004904.0        1000mL Bag        1000           mL             1
# 10396          0.0      HEPARIN BASE         250           mL           250
# 10397          0.0        200 mL Bag         200           mL             1
#
#       form_unit_disp    route  year    month
# 0               VIAL       IM  2146  2146-07
# 1                TAB       PO  2146  2146-07
# 2               SUPP       PR  2146  2146-07
# 3                TAB       PO  2146  2146-07
# 4              UDCUP       PO  2146  2146-07
# ...              ...      ...   ...      ...
# 10393            SYR       IV  2142  2142-11
# 10394           SUPP       PR  2142  2142-11
# 10395            BAG       IV  2142  2142-11
# 10396             mL       IV  2142  2142-11
# 10397            BAG  IV DRIP  2142  2142-11
#
# [10386 rows x 21 columns]

# %%
type(max_value)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp
